# %%
import pathlib
import tifffile as tiff


def generate_positions(length, tile_size, overlap):
    """ 
    Gets tile starting position while including overlap.
    
    ___PARAMETERS___
    length     = total length of image axis (int)
    tile_size  = desired tile size (int)
    overlap    = size of overlap (int)
    """
    #Genererates tile coordinates
    stride = tile_size - overlap
    positions = list(range(0, max(length - tile_size + 1, 1), stride))

    #adding final tile coordinate (if needed)
    last_pos = length - tile_size
    if last_pos < 0:
        last_pos = 0

    if not positions or positions[-1] != last_pos:
        positions.append(last_pos)

    return positions


def tile_tiff(input_path, output_directory, tile_height, tile_width, overlap):
    """
    Processes image into tiles.
    
    ___PARAMETERS___
    input_path       = name of image file for tiling (str)
    output_directory = name of output directory (str)
    tile_height      = desired tile height (int)
    tile_width       = desired tile width (int)
    overlap          = desired overlap (int)
    """  
    #Preprocessing 
    image = tiff.imread(input_path)
    height, width = image.shape[:2]
    y_positions = generate_positions(height, tile_height, overlap)
    x_positions = generate_positions(width, tile_width, overlap)

    #Output map generation
    output_directory = pathlib.Path(output_directory)
    output_directory.mkdir(parents=True, exist_ok=True)

    #Tile processing
    tile_count = 0
    for y in y_positions:
        for x in x_positions:
            #Generates image
            tile = image[y:y + tile_height, x:x + tile_width]
            
            #Stores image
            out_name = f"tile_y{y}_x{x}.tif"
            out_path = output_directory / out_name
            tiff.imwrite(out_path, tile)
            
            tile_count += 1
    print(f"Number of tiles in {output_directory}: {tile_count} tiles")


#Usage
tile_tiff(input_path = "25FU1231.tif", 
          output_directory = "Example_folder", 
          tile_height = 512, 
          tile_width = 512, 
          overlap=64)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26696\6667332.py in ?()
#      63     print(f"Number of tiles in {output_directory}: {tile_count} tiles")
#      64
#      65
#      66 #Usage
# ---> 67 tile_tiff(input_path = "25FU1231.tif",
#      68           output_directory = "Example_folder",
#      69           tile_height = 512,
#      70           tile_width = 512,
#
# ~\AppData\Local\Temp\ipykernel_26696\6667332.py in ?(input_path, output_directory, tile_height, tile_width, overlap)
#      37     tile_width       = desired tile width (int)
#      38     overlap          = desired overlap (int)
#      39     """
#      40     #Preprocessing
# ---> 41     image = tiff.imread(input_path)
#      42     height, width = image.shape[:2]
#      43     y_positions = generate_positions(height, tile_height, overlap)
#      44     x_positions = generate_positions(width, tile_width, overlap)
#
# c:\Users\felix\AppData\Local\Programs\Python\Python313\Lib\site-packages\tifffile\tifffile.py in ?(files, selection, aszarr, key, series, level, squeeze, maxworkers, buffersize, mode, name, offset, size, pattern, axesorder, categories, imread, imreadargs, sort, container, chunkshape, chunkdtype, axestiled, ioworkers, chunkmode, fillvalue, zattrs, multiscales, omexml, superres, out, out_inplace, _multifile, _useframes, **kwargs)
#    1257
#    1258                     from .zarr import zarr_selection
#    1259
#    1260                     return zarr_selection(store, selection, out=out)
# -> 1261                 return tif.asarray(
#    1262                     key=key,
#    1263                     series=series,
#    1264                     level=level,
#
# c:\Users\felix\AppData\Local\Programs\Python\Python313\Lib\site-packages\tifffile\tifffile.py in ?(self, key, series, level, squeeze, out, maxworkers, buffersize)
#    4637             page0 = pages[0]
#    4638             if page0 is None:
#    4639                 msg = 'page is None'
#    4640                 raise ValueError(msg)
# -> 4641             result = page0.asarray(
#    4642                 out=out, maxworkers=maxworkers, buffersize=buffersize
#    4643             )
#    4644         else:
#
# c:\Users\felix\AppData\Local\Programs\Python\Python313\Lib\site-packages\tifffile\tifffile.py in ?(self, out, squeeze, lock, maxworkers, buffersize)
#    9332                     )
#    9333                     fh.open()
#    9334                 keyframe.init_decode()  # init decode function under lock
#    9335
# -> 9336             result = create_output(out, keyframe.shaped, keyframe._dtype)
#    9337
#    9338             def func(
#    9339                 decoderesult: DecodeResult,
#
# c:\Users\felix\AppData\Local\Programs\Python\Python313\Lib\site-packages\tifffile\tifffile.py in ?(out, shape, dtype, mode, suffix, fillvalue)
#   23100     shape = tuple(shape)
#   23101     dtype = numpy.dtype(dtype)
#   23102     if out is None:
#   23103         if fillvalue is None:
# > 23104             return numpy.empty(shape, dtype)
#   23105         if fillvalue:  # fillvalue=0 handled faster by zeros
#   23106             return numpy.full(shape, fillvalue, dtype)
#   23107         return numpy.zeros(shape, dtype)
#
# MemoryError: Unable to allocate 23.3 GiB for an array with shape (1, 1, 92008, 90600, 3) and data type uint8

# %%
length = 1000
tile_size = 100
stride = 100

positions = list(range(0, max(length - tile_size + 1, 1), stride))
print(positions)
# Out:
# [0, 100, 200, 300, 400, 500, 600, 700, 800, 900]
